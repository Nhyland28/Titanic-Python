# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

# %%
#### Import the training and testing data from the Kaggle: https://www.kaggle.com/c/titanic/data
training = pd.read_csv('/Users/Nick/Data_Science/Kaggle/titanic_python/data/train.csv')
testing = pd.read_csv('/Users/Nick/Data_Science/Kaggle/titanic_python/data/test.csv')

# %%
training.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
testing.head()
# Out:
#    PassengerId  Pclass                                          Name     Sex  \
# 0          892       3                              Kelly, Mr. James    male
# 1          893       3              Wilkes, Mrs. James (Ellen Needs)  female
# 2          894       2                     Myles, Mr. Thomas Francis    male
# 3          895       3                              Wirz, Mr. Albert    male
# 4          896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female
#
#     Age  SibSp  Parch   Ticket     Fare Cabin Embarked
# 0  34.5      0      0   330911   7.8292   NaN        Q
# 1  47.0      1      0   363272   7.0000   NaN        S
# 2  62.0      0      0   240276   9.6875   NaN        Q
# 3  27.0      0      0   315154   8.6625   NaN        S
# 4  22.0      1      1  3101298  12.2875   NaN        S

# %%
testing['Survived'] = np.nan

# %%
testing.head()
# Out:
#    PassengerId  Pclass                                          Name     Sex  \
# 0          892       3                              Kelly, Mr. James    male
# 1          893       3              Wilkes, Mrs. James (Ellen Needs)  female
# 2          894       2                     Myles, Mr. Thomas Francis    male
# 3          895       3                              Wirz, Mr. Albert    male
# 4          896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female
#
#     Age  SibSp  Parch   Ticket     Fare Cabin Embarked  Survived
# 0  34.5      0      0   330911   7.8292   NaN        Q       NaN
# 1  47.0      1      0   363272   7.0000   NaN        S       NaN
# 2  62.0      0      0   240276   9.6875   NaN        Q       NaN
# 3  27.0      0      0   315154   8.6625   NaN        S       NaN
# 4  22.0      1      1  3101298  12.2875   NaN        S       NaN

# %%
full = training.append(testing, sort=True)

# %%
full
# Out:
#       Age        Cabin Embarked      Fare  \
# 0    22.0          NaN        S    7.2500
# 1    38.0          C85        C   71.2833
# 2    26.0          NaN        S    7.9250
# 3    35.0         C123        S   53.1000
# 4    35.0          NaN        S    8.0500
# 5     NaN          NaN        Q    8.4583
# 6    54.0          E46        S   51.8625
# 7     2.0          NaN        S   21.0750
# 8    27.0          NaN        S   11.1333
# 9    14.0          NaN        C   30.0708
# 10    4.0           G6        S   16.7000
# 11   58.0         C103        S   26.5500
# 12   20.0          NaN        S    8.0500
# 13   39.0          NaN        S   31.2750
# 14   14.0          NaN        S    7.8542
# 15   55.0          NaN        S   16.0000
# 16    2.0          NaN        Q   29.1250
# 17    NaN          NaN        S   13.0000
# 18   31.0          NaN        S   18.0000
# 19    NaN          NaN        C    7.2250
# 20   35.0          NaN        S   26.0000
# ...

# %%
print(testing.shape)
print(training.shape)
print(full.shape)
# Out:
# (418, 12)
# (891, 12)
# (1309, 12)

# %%
full.describe()
# Out:
#                Age         Fare        Parch  PassengerId       Pclass  \
# count  1046.000000  1308.000000  1309.000000  1309.000000  1309.000000
# mean     29.881138    33.295479     0.385027   655.000000     2.294882
# std      14.413493    51.758668     0.865560   378.020061     0.837836
# min       0.170000     0.000000     0.000000     1.000000     1.000000
# 25%      21.000000     7.895800     0.000000   328.000000     2.000000
# 50%      28.000000    14.454200     0.000000   655.000000     3.000000
# 75%      39.000000    31.275000     0.000000   982.000000     3.000000
# max      80.000000   512.329200     9.000000  1309.000000     3.000000
#
#              SibSp    Survived
# count  1309.000000  891.000000
# mean      0.498854    0.383838
# std       1.041658    0.486592
# min       0.000000    0.000000
# 25%       0.000000    0.000000
# 50%       0.000000    0.000000
# 75%       1.000000    1.000000
# max       8.000000    1.000000

# %%
full.Pclass.value_counts()
# Out:
# 3    709
# 1    323
# 2    277
# Name: Pclass, dtype: int64

# %%
full.dtypes
# Out:
# Age            float64
# Cabin           object
# Embarked        object
# Fare           float64
# Name            object
# Parch            int64
# PassengerId      int64
# Pclass           int64
# Sex             object
# SibSp            int64
# Survived       float64
# Ticket          object
# dtype: object

# %%
#### Convert categorical variables (Embarked, Parch, Pclass, Sex, SibSp, Survived)

#full['Embarked'] = full.Embarked.astype('category')
#full['Parch'] = full.Parch.astype('category')
#full['Pclass'] = full.Pclass.astype('category')
#full['Sex'] = full.Pclass.astype('category')
#full['SibSp'] = full.Pclass.astype('category')
#full['Survived'] = full.Pclass.astype('category')

# %%
full.dtypes
# Out:
# Age             float64
# Cabin            object
# Embarked       category
# Fare            float64
# Name             object
# Parch          category
# PassengerId       int64
# Pclass         category
# Sex            category
# SibSp          category
# Survived       category
# Ticket           object
# dtype: object

# %%
sns.set_style(style='darkgrid')
sns.factorplot('Survived', hue='Sex', data=full)
plt.show()

# %%
sns.factorplot(x='Pclass', y='Survived', hue='Sex', data=full,
              kind='bar')
plt.show()

# %%
# ?sns.catplot()
# Out:
# Object `sns.catplot` not found.

# %%
print(sns.__version__)
# Out:
# 0.8.1

# %%
sns.*?
# Out:
# sns.FacetGrid
# sns.JointGrid
# sns.PairGrid
# sns.__builtins__
# sns.__cached__
# sns.__class__
# sns.__delattr__
# sns.__dict__
# sns.__dir__
# sns.__doc__
# sns.__eq__
# sns.__file__
# sns.__format__
# sns.__ge__
# sns.__getattribute__
# sns.__gt__
# sns.__hash__
# sns.__init__
# sns.__init_subclass__
# sns.__le__
# sns.__loader__
# sns.__lt__
# sns.__name__
# sns.__ne__
# sns.__new__
# sns.__package__
# sns.__path__
# sns.__reduce__
# sns.__reduce_ex__
# sns.__repr__
# sns.__setattr__
# sns.__sizeof__
# sns.__spec__
# sns.__str__
# sns.__subclasshook__
# sns.__version__
# sns.algorithms
# sns.axes_style
# sns.axisgrid
# sns.barplot
# sns.blend_palette
# sns.boxplot
# sns.categorical
# sns.choose_colorbrewer_palette
# sns.choose_cubehelix_palette
# sns.choose_dark_palette
# sns.choose_diverging_palette
# sns.choose_light_palette
# sns.clustermap
# sns.cm
# sns.color_palette
# sns.countplot
# sns.crayon_palette
# sns.crayons
# sns.cubehelix_palette
# sns.dark_palette
# ...

# %%
# ?sns.categorical
# Out:
# Type:        module
# String form: <module 'seaborn.categorical' from '/Users/Nick/anaconda3/lib/python3.6/site-packages/seaborn/categorical.py'>
# File:        ~/anaconda3/lib/python3.6/site-packages/seaborn/categorical.py
# Docstring:   <no docstring>
